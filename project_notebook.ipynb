# %%
import pandas as pd
import numpy as np
import random as rnd
import re

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
# %matplotlib inline

# %%
edgelist_df = pd.read_csv('edge-lists.csv')
ranks_df = pd.read_csv('us-faculty-hiring-networks/data/ranks.csv')

# %%
edgelist_df
# Out:
#        TaxonomyLevel              TaxonomyValue  InstitutionId  \
# 0              Field                Mathematics             82
# 1             Domain  Mathematics and Computing             82
# 2           Academia                   Academia             82
# 3              Field                Mathematics             82
# 4             Domain  Mathematics and Computing             82
# ...              ...                        ...            ...
# 411539      Academia                   Academia            395
# 411540      Academia                   Academia            101
# 411541      Academia                   Academia             50
# 411542      Academia                   Academia             50
# 411543      Academia                   Academia             50
#
#                     InstitutionName  DegreeInstitutionId  \
# 0                      Georgia Tech                243.0
# 1                      Georgia Tech                243.0
# 2                      Georgia Tech                243.0
# 3                      Georgia Tech                251.0
# 4                      Georgia Tech                251.0
# ...                             ...                  ...
# 411539               Texas Southern             557973.0
# 411540  Jewish Theological Seminary                 53.0
# 411541           Concordia Seminary                 58.0
# 411542           Concordia Seminary             548894.0
# 411543           Concordia Seminary             538136.0
#
#                                     DegreeInstitutionName  Total   Men  Women
# 0                                   University of Alabama    1.0   1.0    0.0
# 1                                   University of Alabama    1.0   1.0    0.0
# 2                                   University of Alabama    1.0   1.0    0.0
# 3                                             UC Berkeley    3.0   1.0    2.0
# 4                                             UC Berkeley   20.0  14.0    5.0
# ...                                                   ...    ...   ...    ...
# 411539                     Xavier University of Louisiana    1.0   1.0    0.0
# 411540                   City University of New York, The    1.0   1.0    0.0
# 411541                                               Drew    1.0   1.0    0.0
# 411542  Pontifica Institute di Studi Arabi e d'Islamis...    1.0   0.0    0.0
# 411543                                 Capella University    1.0   1.0    0.0
#
# [411544 rows x 9 columns]

# %%
ranks_df
# Out:
#        Rank  InstitutionId                        InstitutionName  \
# 0         0           31.0     California Institute of Technology
# 1         1          123.0  Massachusetts Institute of Technology
# 2         2           87.0                     Harvard University
# 3         3          167.0                   Princeton University
# 4         4          198.0                    Stanford University
# ...     ...            ...                                    ...
# 11117    39          350.0                  Utah State University
# 11118    40          137.0               Montana State University
# 11119    41          328.0             University of Rhode Island
# 11120    42          190.0          South Dakota State University
# 11121    43          287.0               University of Maine, The
#
#                      TaxonomyValue TaxonomyLevel
# 0                         Academia      Academia
# 1                         Academia      Academia
# 2                         Academia      Academia
# 3                         Academia      Academia
# 4                         Academia      Academia
# ...                            ...           ...
# 11117  Veterinary Medical Sciences         Field
# 11118  Veterinary Medical Sciences         Field
# 11119  Veterinary Medical Sciences         Field
# 11120  Veterinary Medical Sciences         Field
# 11121  Veterinary Medical Sciences         Field
#
# [11122 rows x 5 columns]

# %%
edgelist_df.TaxonomyLevel.value_counts()
# Out:
# Field       219403
# Domain      129857
# Academia     62284
# Name: TaxonomyLevel, dtype: int64

# %%
#edgelist_df=pd.merge(edgelist_df, ranks_df.drop(columns='InstitutionName'), how="left", on=['InstitutionId', 'TaxonomyValue', 'TaxonomyLevel'])

# %% [markdown]
# Replacing Academia with Domain

# %%
edgelist_df.TaxonomyLevel.replace({'Academia':'Domain'}, inplace=True)

# %% [markdown]
# Dropping Field, for now

# %%
edgelist_df=edgelist_df[~(edgelist_df.TaxonomyLevel=="Field")]

# %% [markdown]
# Dropping the TaxonomyLevel columns

# %%
edgelist_df=edgelist_df.drop(columns="TaxonomyLevel")

# %% [markdown]
# Removing the null values of DegreeInstitutionName

# %%
edgelist_df.dropna(subset=['DegreeInstitutionName'], inplace=True)

# %% [markdown]
# Finding out the number of unknown genders

# %%
edgelist_df.Total = edgelist_df.Total-edgelist_df.Men-edgelist_df.Women
edgelist_df.rename(columns = {'Total':'Unknown'}, inplace = True)

# %% [markdown]
# Expanding the number of entries of each gender as a list

# %%
edgelist_df['Gender'] = edgelist_df.apply(lambda x: int(x['Unknown'])*['U']+int(x['Men'])*['M']+int(x['Women'])*['W'], axis=1)

# %% [markdown]
# Exploding along the gender column and dropping the Unknown, Men and Women columns

# %%
edgelist_df=edgelist_df.explode(column=["Gender"])
edgelist_df=edgelist_df.drop(columns=["Unknown","Men","Women"])

# %%
edgelist_df
# Out:
#                     TaxonomyValue  InstitutionId              InstitutionName  \
# 1       Mathematics and Computing             82                 Georgia Tech
# 2                        Academia             82                 Georgia Tech
# 4       Mathematics and Computing             82                 Georgia Tech
# 4       Mathematics and Computing             82                 Georgia Tech
# 4       Mathematics and Computing             82                 Georgia Tech
# ...                           ...            ...                          ...
# 411539                   Academia            395               Texas Southern
# 411540                   Academia            101  Jewish Theological Seminary
# 411541                   Academia             50           Concordia Seminary
# 411542                   Academia             50           Concordia Seminary
# 411543                   Academia             50           Concordia Seminary
#
#         DegreeInstitutionId  \
# 1                     243.0
# 2                     243.0
# 4                     251.0
# 4                     251.0
# 4                     251.0
# ...                     ...
# 411539             557973.0
# 411540                 53.0
# 411541                 58.0
# 411542             548894.0
# 411543             538136.0
#
#                                     DegreeInstitutionName Gender
# 1                                   University of Alabama      M
# 2                                   University of Alabama      M
# 4                                             UC Berkeley      U
# 4                                             UC Berkeley      M
# 4                                             UC Berkeley      M
# ...                                                   ...    ...
# 411539                     Xavier University of Louisiana      M
# 411540                   City University of New York, The      M
# 411541                                               Drew      M
# 411542  Pontifica Institute di Studi Arabi e d'Islamis...      U
# 411543                                 Capella University      M
#
# [568379 rows x 6 columns]

# %%
edgelist_df.isna().sum()
# Out:
# TaxonomyValue            0
# InstitutionId            0
# InstitutionName          0
# DegreeInstitutionId      0
# DegreeInstitutionName    0
# Gender                   0
# dtype: int64

# %%
edgelist_df=pd.merge(edgelist_df, ranks_df.drop(columns='InstitutionId'), how="left", on=['InstitutionName', 'TaxonomyValue', 'TaxonomyLevel'])

# %%
#edgelist_df.rename(columns = {'TaxonomyValue':'Domain'}, inplace = True)

# %%
edgelist_df.Rank.isnull().sum()
# Out:
# 29342

# %%
edgelist_df.dropna(subset=['Rank'])
# Out:
#        TaxonomyValue  InstitutionId              InstitutionName  \
# 1           Academia             82                 Georgia Tech
# 22          Academia             82                 Georgia Tech
# 23          Academia             82                 Georgia Tech
# 24          Academia             82                 Georgia Tech
# 25          Academia             82                 Georgia Tech
# ...              ...            ...                          ...
# 568374      Academia            395               Texas Southern
# 568375      Academia            101  Jewish Theological Seminary
# 568376      Academia             50           Concordia Seminary
# 568377      Academia             50           Concordia Seminary
# 568378      Academia             50           Concordia Seminary
#
#         DegreeInstitutionId  \
# 1                     243.0
# 22                    251.0
# 23                    251.0
# 24                    251.0
# 25                    251.0
# ...                     ...
# 568374             557973.0
# 568375                 53.0
# 568376                 58.0
# 568377             548894.0
# 568378             538136.0
#
#                                     DegreeInstitutionName Gender   Rank  \
# 1                                   University of Alabama      M   44.0
# 22                                            UC Berkeley      U   44.0
# 23                                            UC Berkeley      U   44.0
# 24                                            UC Berkeley      U   44.0
# 25                                            UC Berkeley      U   44.0
# ...                                                   ...    ...    ...
# 568374                     Xavier University of Louisiana      M  296.0
# 568375                   City University of New York, The      M   41.0
# 568376                                               Drew      M  274.0
# 568377  Pontifica Institute di Studi Arabi e d'Islamis...      U  274.0
# 568378                                 Capella University      M  274.0
#
#        TaxonomyLevel
# 1           Academia
# 22          Academia
# 23          Academia
# 24          Academia
# 25          Academia
# ...              ...
# 568374      Academia
# 568375      Academia
# 568376      Academia
# 568377      Academia
# 568378      Academia
#
# [539037 rows x 8 columns]

# %%
edgelist_df.TaxonomyValue.value_counts()
# Out:
# Academia                     274474
# Natural Sciences              69014
# Medicine and Health           51103
# Humanities                    41096
# Social Sciences               37554
# Engineering                   28811
# Applied Sciences              27335
# Mathematics and Computing     25412
# Education                     13580
# Name: TaxonomyValue, dtype: int64
